-- %%
SELECT d.year, d.month, SUM(f.total_revenue) AS revenue_month
FROM `Amazon-DataEngineering`.servidorsdeprueba.dbo.fact_sales f
JOIN `Amazon-DataEngineering`.servidorsdeprueba.dbo.dim_date_sk d
    ON f.date_key = d.date_key
GROUP BY d.year, d.month
ORDER BY d.year, d.month;
-- Out:
-- StatementMeta(, 16f58827-6634-4568-a572-86b06b153074, 34, Finished, Available, Finished)
-- <Spark SQL result set with 24 rows and 3 fields>
